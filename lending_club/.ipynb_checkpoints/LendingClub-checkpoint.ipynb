# %% [markdown]
# # Are religious Americans more likely to repay loans?
# The recent rise of peer-to-peer lending has been stunning. Starting from zero a few years ago, platforms like Lending Club are already placing $10 billion of unsecured personal loans per year.
#
# The concept is simple: a borrower fills in an application, investors choose to fund part or all of the loan, and the platform takes care of fine details, like collecting payments and annoying late borrowers. In theory, this disintermediation of banks from consumer credit lowers borrowing rates, improves investor returns, and leaves a healthy margin for the platform's profits.
#
# The platforms publish anonymized default history from previous loans. This data helps investors make smarter decisions about future loans - attracting more investment dollars. Investors use the data to try to pick loans with a high interest rate, but a lower likelihood of default.

# %% [markdown]
# ## Data set
# For now, I will use only 36 month loans originating before 2013 (maturing before 2016). For now, I will restrict my data set to 2012 (as we go back further, the underwriting standards change). If I fill rows to handle current loans (see below), I will bring in more recent data.

# %% [markdown]
# ## Predictive factors
# Many factors look to be of interest. Obvious ones include:
# - FICO Score
# - Debt to Income ratio
# - Size of loan
#
# Additional factors that people have provided some evidence for:
# - Loan description length
#   - Long descriptions are bad: http://drjasondavis.com/blog/2012/04/08/lending-club-loan-analysis-making-money-with-logistic-regression
#   - Long descriptions are good: https://lendingclubmodeling.wordpress.com/2011/04/25/why-loan-descriptions-and-qa-matter/
# - Loan purpose: http://blog.lendingrobot.com/research/predicting-the-number-of-payments-in-peer-lending/
#
# Other useful articles:
# - http://blog.lendingrobot.com/research/predicting-returns-for-ongoing-loans/
# - http://kldavenport.com/gradient-boosting-analysis-of-lendingclubs-data/

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Predicted variable
# We're ultimately concerned with risk-adjusted return. However, analysis is simpler with certain assumptions. These may be revisited in a future analysis:
# - Risk-adjustment can be handled separately
# - Return = interest rate - probability of default * loss given default
# - PD follows the same hazard curve, regardless of risk grade or other factors
# - LGD is the same for different risk grades and only depends on lateness severity
#
# Therefore, we can focus on PD only.
#
# Explore:
# - shape of default curve at different risk grades
# - chance of late payments developing into default at different grades
# - recovery amounts at different grades
# - do late fees help out?

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Caveats
# This study has focused on a methodology for answering sociological questions and predicting defaults. Other issues to resolve for successful investing in P2P include:
# - API access: smart investors, such as hedge funds are rumored to quickly cream off the best loans. Any superior statistical view must also compete on execution speed.
# - Returns should be risk-adjusted for proper comparison to alternative investments, such as the S&P 500. An examination of similar grades of unsecuritized personal loans (credit cards) across the entire credit cycle would help capture both beta and true risk of default.
# - Lending Club uses NAR (Net Annualized Return, a non-standard method that assumes all current loans will pay 100%) http://danielodio.com/one-year-in-lending-money-to-complete-strangers-via-an-api-and-why-you-should-try-it
# - Investment size: what is the proper amount to invest in each loan to achieve the Kelly Criterion?
# - Loans do not receive capital gains treatment and are taxed as ordinary income.

# %% [markdown]
# ## Load data from Lending Club
# Lending Club provides information on all past applications (and current loan status)

# %% [markdown]
# ## Input files
# - **LoanStats3a.csv.zip:** 2007-2011 Lending Club default history from https://www.lendingclub.com/info/download-data.action
# - **LoanStats3b.csv.zip:** 2012-2013 Lending Club default history
# - **LoanStats3c.csv.zip:** 2013-2014 Lending Club default history (currently reading this one only)
# - **LoanStats3d.csv.zip:** 2015-2015 Lending Club default history
#   - According to http://www.lendingmemo.com/lendingrobot-investing-review/, lending standards changed drastically starting in 2013
# - **ZIP_COUNTY_122015.xlsx:** list of zip codes and county codes
# - **national_county.txt:** list of states and counties mapped to code from US Census
# - **2010.csv:** list of US counties, population, congregations, and adherents from http://www.rcms2010.org/
#   - This website also has info breaking down into specific religion
# - **US_elect_county:** 2012 presidential elections by county from http://www.theguardian.com/news/datablog/2012/nov/07/us-2012-election-county-results-download

# %%
import pandas as pd
pd.set_option('display.max_columns', 100)
# %matplotlib inline
# religious adherents 
zip_counties = pd.read_excel('ZIP_COUNTY_122015.xlsx', skiprows = 0, header = 0)
zip_counties['ZIP'] = zip_counties['ZIP'].str.zfill(5)
zip_counties.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-ff00fd2df541> in <module>()
#       4 # religious adherents
#       5 zip_counties = pd.read_excel('ZIP_COUNTY_122015.xlsx', skiprows = 0, header = 0)
# ----> 6 zip_counties['ZIP'] = zip_counties['ZIP'].str.zfill(5)
#       7 zip_counties.head()
#
# //anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2239                 or name in self._metadata
#    2240                 or name in self._accessors):
# -> 2241             return object.__getattribute__(self, name)
#    2242         else:
#    2243             if name in self._info_axis:
#
# //anaconda/lib/python2.7/site-packages/pandas/core/base.pyc in __get__(self, instance, owner)
#     186             # this ensures that Series.str.<method> is well defined
#     187             return self.accessor_cls
# --> 188         return self.construct_accessor(instance)
#     189
#     190     def __set__(self, instance, value):
#
# //anaconda/lib/python2.7/site-packages/pandas/core/base.pyc in _make_str_accessor(self)
#     526             # but that isn't practical for performance reasons until we have a
#     527             # str dtype (GH 9343)
# --> 528             raise AttributeError("Can only use .str accessor with string "
#     529                                  "values, which use np.object_ dtype in "
#     530                                  "pandas")
#
# AttributeError: Can only use .str accessor with string values, which use np.object_ dtype in pandas

# %%
import pandas as pd
pd.set_option('display.max_columns', 100)
# %matplotlib inline
# religious adherents 
national_county = pd.read_csv('national_county.txt', 
    names=['State', 'State_Code', 'County_Code', 'County', 'H1'], dtype={1: str, 2: str})
# combine into needed fields
national_county['County_Code_Full'] = national_county['State_Code'] + national_county['County_Code']
national_county['County_Full'] = national_county['County'].str[:-7] + ', ' + national_county['State']
national_county.head()
# Out:
#   State State_Code County_Code          County  H1 County_Code_Full  \
# 0    AL         01         001  Autauga County  H1            01001
# 1    AL         01         003  Baldwin County  H1            01003
# 2    AL         01         005  Barbour County  H1            01005
# 3    AL         01         007     Bibb County  H1            01007
# 4    AL         01         009   Blount County  H1            01009
#
#    County_Full
# 0  Autauga, AL
# 1  Baldwin, AL
# 2  Barbour, AL
# 3     Bibb, AL
# 4   Blount, AL

# %%
import pandas as pd
pd.set_option('display.max_columns', 100)
# %matplotlib inline
# religious adherents 
religion = pd.read_csv('2010.csv', skiprows = 2, header = 1)
religion.head()
# Out:
#   County or Equivalent  Population  PopRank  Adherents  AdhRank  \
# 0          Autauga, AL       54571      917      36938      691
# 1          Baldwin, AL      182265      338      96918      303
# 2          Barbour, AL       27457     1516      15101     1392
# 3             Bibb, AL       22915     1693      11430     1671
# 4           Blount, AL       57322      884      37352      685
#
#    Congregations  ConRank  Adherents %  Adh% Rank  \
# 0            106      831         67.7        546
# 1            271      248         53.2       1329
# 2             89     1024         55.0       1206
# 3             81     1152         49.9       1564
# 4            156      510         65.2        662
#
#    Congregations Per 10K People  Con Per 10K Rank
# 0                            19              1799
# 1                            15              2268
# 2                            32               701
# 3                            35               539
# 4                            27              1072

# %%
import pandas as pd
pd.set_option('display.max_columns', 100)
# %matplotlib inline
# 2012-2013 loan data - files are available from deeper history
# had to unzip file
past_loans = pd.read_csv('LoanStats3b.csv', header = 1, index_col=0, skiprows=0, skip_footer=2, engine='python')
past_loans['term'] = past_loans['term'].astype('category')
past_loans['grade'] = past_loans['grade'].astype('category')
past_loans['sub_grade'] = past_loans['sub_grade'].astype('category')
past_loans['home_ownership'] = past_loans['home_ownership'].astype('category')
past_loans['verification_status'] = past_loans['verification_status'].astype('category')

# Making assumption that any currently late loans are bad; may need to revisit
# Assumptions from Lending Club https://www.lendingclub.com/account/investorReturnsAdjustments.action
# Current 0% loss
# In Grace Period 28% loss
# Late 16-30 days 58% loss
# Late 31-120 days 74% loss
# Default 89% loss
di = {'Current': 'Good', 'Fully Paid': 'Good', 'Charged Off': 'Bad', 'Late (31-120 days)': 'Bad',
       'In Grace Period': 'Bad', 'Late (16-30 days)': 'Bad', 'Default': 'Bad'}
# past_loans.replace({'loan_status': di}, inplace=True)
past_loans['loan_status'] = past_loans['loan_status'].astype('category')
past_loans['pymnt_plan'] = past_loans['pymnt_plan'].astype('category')
past_loans['purpose'] = past_loans['purpose'].astype('category')
past_loans['application_type'] = past_loans['application_type'].astype('category')

# convert dates
past_loans['issue_d'] = pd.to_datetime(past_loans['issue_d'])
past_loans['earliest_cr_line'] = pd.to_datetime(past_loans['earliest_cr_line'])
past_loans['last_pymnt_d'] = pd.to_datetime(past_loans['last_pymnt_d'])
past_loans['next_pymnt_d'] = pd.to_datetime(past_loans['next_pymnt_d'])
past_loans['last_credit_pull_d'] = pd.to_datetime(past_loans['last_credit_pull_d'])
past_loans['issue_d'] = pd.to_datetime(past_loans['issue_d'])

# convert floats
past_loans['int_rate'] = pd.to_numeric(past_loans['int_rate'].str.extract('(.*)%'))/100

# drop pointless data
past_loans=past_loans.dropna(axis=1,how='all')
past_loans.drop('application_type',axis = 1) # only contains "individual"

# drop data that's not 2012 origination and 36 months term
past_loans = past_loans.drop(past_loans[(past_loans.issue_d >= '2012-07-01') | (past_loans.term == ' 60 months')].index)

past_loans.head()
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 1377559    1622372       2500         2500             2500   36 months
# 1377635    1621835       3000         3000             2750   36 months
# 1377314    1621503       5600         5600             5600   36 months
# 1327173    1572525       2800         2800             2800   36 months
# 1363816    1607830       1925         1925             1925   36 months
#
#          int_rate  installment grade sub_grade                      emp_title  \
# id
# 1377559    0.1465        86.24     C        C2             value concepts inc
# 1377635    0.0790        93.88     A        A4  Washoe County School District
# 1377314    0.1922       205.90     D        D5                       OpenText
# 1327173    0.0762        87.26     A        A3             The Dawson Academy
# 1363816    0.1074        62.79     B        B2                            PPT
#
#         emp_length home_ownership  annual_inc verification_status    issue_d  \
# id
# 1377559  10+ years       MORTGAGE       53000     Source Verified 2012-06-01
# 1377635  10+ years       MORTGAGE       45600        Not Verified 2012-06-01
# 1377314    6 years           RENT       76320     Source Verified 2012-06-01
# 1327173    7 years       MORTGAGE       65000        Not Verified 2012-06-01
# 1363816   < 1 year            OWN       20700        Not Verified 2012-06-01
#
#         loan_status pymnt_plan  \
# id
# 1377559  Fully Paid          n
# 1377635  Fully Paid          n
# 1377314  Fully Paid          n
# 1327173  Fully Paid          n
# 1363816  Fully Paid          n
#
#                                                        url  \
# id
# 1377559  https://www.lendingclub.com/browse/loanDetail....
# 1377635  https://www.lendingclub.com/browse/loanDetail....
# 1377314  https://www.lendingclub.com/browse/loanDetail....
# 1327173  https://www.lendingclub.com/browse/loanDetail....
# 1363816  https://www.lendingclub.com/browse/loanDetail....
#
#                                                       desc  \
# id
# 1377559    Borrower added on 06/20/12 > home repairs th...
# 1377635                                                NaN
# 1377314    Borrower added on 06/20/12 > Consolidation<b...
# 1327173    Borrower added on 06/20/12 > This loan is go...
# 1363816    Borrower added on 06/20/12 > Help pay for ki...
#
#                     purpose                         title zip_code addr_state  \
# id
# 1377559    home_improvement                 loan for life    306xx         GA
# 1377635                 car                        My Car    894xx         NV
# 1377314  debt_consolidation                      Consloan    323xx         FL
# 1327173      major_purchase                      Spa Loan    140xx         NY
# 1363816    home_improvement  Materials for home addition.    857xx         AZ
#
#            dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# id
# 1377559  17.00            0       1987-03-01               0
# 1377635   8.21            0       1998-05-01               0
# 1377314  17.30            0       2008-09-01               0
# 1327173   5.32            0       1992-02-01               0
# 1363816   4.23            0       2002-09-01               2
#
#          mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# id
# 1377559                      30                     NaN         8        0
# 1377635                     NaN                     NaN         4        0
# 1377314                     NaN                     NaN         9        0
# 1327173                     NaN                     NaN         4        0
# 1363816                     NaN                     NaN         7        0
#
#          revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# id
# 1377559       3222      54.6%         15                   f          0
# 1377635       1046      26.1%         21                   f          0
# 1377314       3445      91.5%         13                   f          0
# 1327173        818       4.1%          6                   f          0
# 1363816       2387      21.3%         10                   f          0
#
#          out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# id
# 1377559              0  3104.435553          3104.44             2500
# 1377635              0  3379.306095          3097.70             3000
# 1377314              0  7093.693707          7093.69             5600
# 1327173              0  3141.029828          3141.03             2800
# 1363816              0  1975.565136          1975.57             1925
#
#          total_rec_int  total_rec_late_fee  recoveries  \
# id
# 1377559         604.44                   0           0
# 1377635         379.31                   0           0
# 1377314        1493.69                   0           0
# 1327173         341.03                   0           0
# 1363816          50.57                   0           0
#
#          collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d  \
# id
# 1377559                        0   2015-07-01            89.38          NaT
# 1377635                        0   2015-07-01            96.03          NaT
# 1377314                        0   2014-05-01          2783.95          NaT
# 1327173                        0   2015-07-01            89.64          NaT
# 1363816                        0   2012-10-01          1850.67          NaT
#
#         last_credit_pull_d  collections_12_mths_ex_med  \
# id
# 1377559         2016-02-01                           0
# 1377635         2016-02-01                           0
# 1377314         2016-02-01                           0
# 1327173         2015-06-01                           0
# 1363816         2014-05-01                           0
#
#          mths_since_last_major_derog  policy_code application_type  \
# id
# 1377559                          NaN            1       INDIVIDUAL
# 1377635                          NaN            1       INDIVIDUAL
# 1377314                          NaN            1       INDIVIDUAL
# 1327173                          NaN            1       INDIVIDUAL
# 1363816                          NaN            1       INDIVIDUAL
#
#          acc_now_delinq  tot_coll_amt  tot_cur_bal  total_rev_hi_lim  \
# id
# 1377559               0           NaN          NaN               NaN
# 1377635               0           NaN          NaN               NaN
# 1377314               0           NaN          NaN               NaN
# 1327173               0           NaN          NaN               NaN
# 1363816               0           NaN          NaN               NaN
#
#          acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 1371821    0.0603       121.75     A        A1
# 1370151    0.1311       101.25     B        B4
# 1365045    0.1212        39.93     B        B3
# 1371169    0.1367       132.67     B        B5
# 1370829    0.1212        49.91     B        B3
# 1370575    0.1311        84.37     B        B4
# ...           ...          ...   ...       ...
# 1365476    0.1825        36.28     D        D3
# 1365453    0.0890       158.77     A        A5
# 1365307    0.1799       260.27     D        D2
# 1356946    0.1727       217.41     D        D1
# 1365261    0.1999       292.63     E        E1
# 1365148    0.1367       340.18     B        B5
# 1365251    0.1531       152.33     C        C3
# 1365073    0.1727       429.45     D        D1
# 1361956    0.1212        86.51     B        B3
# 1358362    0.1799       260.27     D        D2
# 1364989    0.1367       193.91     B        B5
# 1364924    0.2050       299.36     E        E2
# 1364796    0.1311       134.99     B        B4
# 1364891    0.1727       536.81     D        D1
# 1364734    0.1855       284.33     D        D4
# 1364887    0.0603       106.53     A        A1
# 1340073    0.1399       102.52     C        C1
# 1364789    0.1999       178.37     E        E1
# 1364776    0.1799       542.22     D        D2
# 1364551    0.1799       361.48     D        D2
# 1356950    0.1825       489.76     D        D3
# 1364599    0.1581       252.46     C        C4
# 1364520    0.1922       896.21     D        D5
# 1364576    0.1212       199.63     B        B3
# 1364490    0.1212        46.59     B        B3
# 1364451    0.1367       122.47     B        B5
# 1364442    0.1922       551.52     D        D5
# 1364267    0.1727       733.64     D        D1
# 1364257    0.1999       928.97     E        E1
# 1364193    0.1799       722.95     D        D2
#
#                                         emp_title emp_length home_ownership  \
# id
# 1377559                        value concepts inc  10+ years       MORTGAGE
# 1377635             Washoe County School District  10+ years       MORTGAGE
# 1377314                                  OpenText    6 years           RENT
# 1327173                        The Dawson Academy    7 years       MORTGAGE
# 1363816                                       PPT   < 1 year            OWN
# 1376522                                    Fiserv    8 years           RENT
# 1375343                                      CHKD   < 1 year           RENT
# 1375440                           bank of america    2 years       MORTGAGE
# 1375177                         James Slaman, DDS    6 years           RENT
# 1375009                     Dekalb Farmers market    5 years           RENT
# 1374780                            Sonoma Academy    4 years       MORTGAGE
# 1374986                     Department of Defense    5 years       MORTGAGE
# 1342179                         Army Audit Agency    5 years           RENT
# 1374981                        Ashford University   < 1 year           RENT
# 1374225                                 Insperity    9 years           RENT
# 1373961                                       NaN        n/a       MORTGAGE
# 1373675                                    Target    6 years           RENT
# 1373438                Clearview Health and Rehab   < 1 year           RENT
# 1372954                                     kohls    8 years           RENT
# 1371334                               Electralloy     1 year           RENT
# 1372846                                  PNC Bank    2 years           RENT
# 1372533                                       NaN    6 years            OWN
# 1372089              Huntsville Memorial Hospital    5 years       MORTGAGE
# 1370253                                State Farm     1 year       MORTGAGE
# 1371821                         POLAR ELECTRO INC    6 years           RENT
# 1370151                           US Marine Corps  10+ years       MORTGAGE
# 1365045                                    Target    4 years       MORTGAGE
# 1371169                                       FGH    3 years       MORTGAGE
# 1370829                         Buda Woodworks LP  10+ years       MORTGAGE
# 1370575                                     Lowes    5 years           RENT
# ...                                           ...        ...            ...
# 1365476                                    Oakley    3 years           RENT
# 1365453                      Bombardier Aerospace    3 years           RENT
# 1365307                       John Bales Atorneys    5 years       MORTGAGE
# 1356946     Virginia Department of Transportation     1 year           RENT
# 1365261                                       IRS  10+ years           RENT
# 1365148                       H and H Enterprises  10+ years       MORTGAGE
# 1365251                      Helbling Supply Inc.    3 years           RENT
# 1365073                       Mercy Assisted Care    5 years       MORTGAGE
# 1361956       Tennessee Attorney General's Office  10+ years       MORTGAGE
# 1358362                                       EMC   < 1 year           RENT
# 1364989                                    Rich's    5 years            OWN
# 1364924              Bones Roadhouse Bar and Grub   < 1 year       MORTGAGE
# 1364796                               CNA Surety     2 years           RENT
# 1364891                                 Starbucks    7 years           RENT
# 1364734                                 Air Force  10+ years           RENT
# 1364887                          Capital One Bank    6 years           RENT
# 1340073                    Pangean-CMD Associates    4 years           RENT
# 1364789                                       NaN        n/a       MORTGAGE
# 1364776                                     USDTL  10+ years           RENT
# 1364551                   huntsville city schools  10+ years       MORTGAGE
# 1356950                                   GA Hope   < 1 year           RENT
# 1364599                             MIQ Logistics    6 years       MORTGAGE
# 1364520  San Joaquin Community Hospital,Mercy Hos    4 years       MORTGAGE
# 1364576                          Joe's Stone Crab    6 years           RENT
# 1364490                       Los Angeles Unified  10+ years       MORTGAGE
# 1364451                         Farmers Insurance    7 years       MORTGAGE
# 1364442                  Centurion Auto Transport  10+ years       MORTGAGE
# 1364267                 Jack Henry and Associates    5 years       MORTGAGE
# 1364257                           Joules angstrom  10+ years       MORTGAGE
# 1364193                           Schreiber Foods  10+ years       MORTGAGE
#
#          annual_inc verification_status    issue_d  loan_status pymnt_plan  \
# id
# 1377559       53000     Source Verified 2012-06-01   Fully Paid          n
# 1377635       45600        Not Verified 2012-06-01   Fully Paid          n
# 1377314       76320     Source Verified 2012-06-01   Fully Paid          n
# 1327173       65000        Not Verified 2012-06-01   Fully Paid          n
# 1363816       20700        Not Verified 2012-06-01   Fully Paid          n
# 1376522       75000        Not Verified 2012-06-01  Charged Off          n
# 1375343      135000        Not Verified 2012-06-01   Fully Paid          n
# 1375440       56200        Not Verified 2012-06-01   Fully Paid          n
# 1375177       36500        Not Verified 2012-06-01   Fully Paid          n
# 1375009       28000     Source Verified 2012-06-01   Fully Paid          n
# 1374780       89000     Source Verified 2012-06-01   Fully Paid          n
# 1374986       50000        Not Verified 2012-06-01   Fully Paid          n
# 1342179       79000            Verified 2012-06-01   Fully Paid          n
# 1374981       41000        Not Verified 2012-06-01   Fully Paid          n
# 1374225       51947     Source Verified 2012-06-01   Fully Paid          n
# 1373961       45000        Not Verified 2012-06-01   Fully Paid          n
# 1373675       23000        Not Verified 2012-06-01  Charged Off          n
# 1373438       70000     Source Verified 2012-06-01   Fully Paid          n
# 1372954       12500            Verified 2012-06-01   Fully Paid          n
# 1371334       37000        Not Verified 2012-06-01   Fully Paid          n
# 1372846       20143        Not Verified 2012-06-01   Fully Paid          n
# 1372533       30000            Verified 2012-06-01  Charged Off          n
# 1372089       50000        Not Verified 2012-06-01   Fully Paid          n
# 1370253       30000        Not Verified 2012-06-01  Charged Off          n
# 1371821       45000     Source Verified 2012-06-01   Fully Paid          n
# ...                    ...             ...                         ...
# 1365476              29355            4000                         NaN
# 1365453               2729            6102                         NaN
# 1365307              25203           15100                         NaN
# 1356946              41690            5800                         NaN
# 1365261               8139             300                         NaN
# 1365148               5250            5200                         NaN
# 1365251              12922            3400                         NaN
# 1365073              53837            8642                         NaN
# 1361956               3429            1500                         NaN
# 1358362              41367           15400                         NaN
# 1364989               8531           11300                         NaN
# 1364924               8509            8700                         NaN
# 1364796              22802           13800                         NaN
# 1364891               8211            6700                         NaN
# 1364734              40888           14200                         NaN
# 1364887              15679           22500                         NaN
# 1340073              47901           16300                         NaN
# 1364789              23314               0                         NaN
# 1364776              27777            4200                         NaN
# 1364551              31354            5400                         NaN
# 1356950             128385           12300                         NaN
# 1364599              33541            5400                         NaN
# 1364520              83650           10000                         NaN
# 1364576              43390            9800                         NaN
# 1364490              16921           13800                         NaN
# 1364451              26705            5200                         NaN
# 1364442              69922           24800                         NaN
# 1364267              44052           16200                         NaN
# 1364257              68719           31100                         NaN
# 1364193              40969           13700                         NaN
#
# [100 rows x 93 columns]

# %%
past_loans[(past_loans['loan_status'] != "Charged Off") & (past_loans['loan_status'] != "Fully Paid")].head(100)
# Out:
# Empty DataFrame
# Columns: [member_id, loan_amnt, funded_amnt, funded_amnt_inv, term, int_rate, installment, grade, sub_grade, emp_title, emp_length, home_ownership, annual_inc, verification_status, issue_d, loan_status, pymnt_plan, url, desc, purpose, title, zip_code, addr_state, dti, delinq_2yrs, earliest_cr_line, inq_last_6mths, mths_since_last_delinq, mths_since_last_record, open_acc, pub_rec, revol_bal, revol_util, total_acc, initial_list_status, out_prncp, out_prncp_inv, total_pymnt, total_pymnt_inv, total_rec_prncp, total_rec_int, total_rec_late_fee, recoveries, collection_recovery_fee, last_pymnt_d, last_pymnt_amnt, next_pymnt_d, last_credit_pull_d, collections_12_mths_ex_med, mths_since_last_major_derog, policy_code, application_type, acc_now_delinq, tot_coll_amt, tot_cur_bal, total_rev_hi_lim, acc_open_past_24mths, avg_cur_bal, bc_open_to_buy, bc_util, chargeoff_within_12_mths, delinq_amnt, mo_sin_old_il_acct, mo_sin_old_rev_tl_op, mo_sin_rcnt_rev_tl_op, mo_sin_rcnt_tl, mort_acc, mths_since_recent_bc, mths_since_recent_bc_dlq, mths_since_recent_inq, mths_since_recent_revol_delinq, num_accts_ever_120_pd, num_actv_bc_tl, num_actv_rev_tl, num_bc_sats, num_bc_tl, num_il_tl, num_op_rev_tl, num_rev_accts, num_rev_tl_bal_gt_0, num_sats, num_tl_120dpd_2m, num_tl_30dpd, num_tl_90g_dpd_24m, num_tl_op_past_12m, pct_tl_nvr_dlq, percent_bc_gt_75, pub_rec_bankruptcies, tax_liens, tot_hi_cred_lim, total_bal_ex_mort, total_bc_limit, total_il_high_credit_limit]
# Index: []

# %% [markdown]
# # Explore different categorical data
# What values are inside the categorical fields?

# %%
pd.unique(past_loans['term'])
# Out:
# array([' 36 months'], dtype=object)

# %%
pd.unique(past_loans['grade'])
# Out:
# array(['C', 'A', 'D', 'B', 'E', 'G', 'F'], dtype=object)

# %%
pd.unique(past_loans['sub_grade'])
# Out:
# array(['C2', 'A4', 'D5', 'A3', 'B2', 'B1', 'B5', 'A1', 'C5', 'B3', 'C1',
#        'E1', 'B4', 'D1', 'C4', 'D3', 'A2', 'E2', 'E4', 'A5', 'D2', 'C3',
#        'D4', 'G1', 'G2', 'E5', 'F1', 'G3', 'F5', 'F2', 'E3', 'F3', 'G4',
#        'G5', 'F4'], dtype=object)

# %%
pd.unique(past_loans['home_ownership'])
# Out:
# array(['MORTGAGE', 'RENT', 'OWN'], dtype=object)

# %%
pd.unique(past_loans['verification_status'])
# Out:
# array(['Source Verified', 'Not Verified', 'Verified'], dtype=object)

# %%
pd.unique(past_loans['loan_status'])
# Out:
# array(['Fully Paid', 'Charged Off'], dtype=object)

# %%
pd.unique(past_loans['pymnt_plan'])
# Out:
# array(['n'], dtype=object)

# %%
pd.unique(past_loans['purpose'])
# Out:
# array(['home_improvement', 'car', 'debt_consolidation', 'major_purchase',
#        'moving', 'credit_card', 'vacation', 'small_business', 'other',
#        'wedding', 'medical', 'house', 'renewable_energy'], dtype=object)

# %% [markdown]
# # Examine field types and amount of data
# Is there any missing data?

# %%
past_loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14967 entries, 1377559 to 1058722
# Data columns (total 93 columns):
# member_id                         14967 non-null int64
# loan_amnt                         14967 non-null int64
# funded_amnt                       14967 non-null int64
# funded_amnt_inv                   14967 non-null float64
# term                              14967 non-null category
# int_rate                          14967 non-null float64
# installment                       14967 non-null float64
# grade                             14967 non-null category
# sub_grade                         14967 non-null category
# emp_title                         13938 non-null object
# emp_length                        14967 non-null object
# home_ownership                    14967 non-null category
# annual_inc                        14967 non-null float64
# verification_status               14967 non-null category
# issue_d                           14967 non-null datetime64[ns]
# loan_status                       14967 non-null category
# pymnt_plan                        14967 non-null category
# url                               14967 non-null object
# desc                              8511 non-null object
# purpose                           14967 non-null category
# title                             14967 non-null object
# zip_code                          14967 non-null object
# addr_state                        14967 non-null object
# dti                               14967 non-null float64
# delinq_2yrs                       14967 non-null int64
# earliest_cr_line                  14967 non-null datetime64[ns]
# inq_last_6mths                    14967 non-null int64
# mths_since_last_delinq            4777 non-null float64
# mths_since_last_record            434 non-null float64
# open_acc                          14967 non-null int64
# pub_rec                           14967 non-null int64
# revol_bal                         14967 non-null int64
# revol_util                        14947 non-null object
# total_acc                         14967 non-null int64
# initial_list_status               14967 non-null object
# out_prncp                         14967 non-null float64
# out_prncp_inv                     14967 non-null float64
# total_pymnt                       14967 non-null float64
# total_pymnt_inv                   14967 non-null float64
# total_rec_prncp                   14967 non-null float64
# total_rec_int                     14967 non-null float64
# total_rec_late_fee                14967 non-null float64
# recoveries                        14967 non-null float64
# collection_recovery_fee           14967 non-null float64
# last_pymnt_d                      14949 non-null datetime64[ns]
# last_pymnt_amnt                   14967 non-null float64
# next_pymnt_d                      0 non-null datetime64[ns]
# last_credit_pull_d                14967 non-null datetime64[ns]
# collections_12_mths_ex_med        14967 non-null int64
# mths_since_last_major_derog       0 non-null float64
# policy_code                       14967 non-null int64
# application_type                  14967 non-null category
# acc_now_delinq                    14967 non-null int64
# tot_coll_amt                      0 non-null float64
# tot_cur_bal                       0 non-null float64
# total_rev_hi_lim                  0 non-null float64
# acc_open_past_24mths              8942 non-null float64
# avg_cur_bal                       0 non-null float64
# bc_open_to_buy                    8827 non-null float64
# bc_util                           8821 non-null float64
# chargeoff_within_12_mths          14967 non-null int64
# delinq_amnt                       14967 non-null int64
# mo_sin_old_il_acct                0 non-null float64
# mo_sin_old_rev_tl_op              0 non-null float64
# mo_sin_rcnt_rev_tl_op             0 non-null float64
# mo_sin_rcnt_tl                    0 non-null float64
# mort_acc                          8942 non-null float64
# mths_since_recent_bc              8840 non-null float64
# mths_since_recent_bc_dlq          0 non-null float64
# mths_since_recent_inq             7580 non-null float64
# mths_since_recent_revol_delinq    2138 non-null float64
# num_accts_ever_120_pd             0 non-null float64
# num_actv_bc_tl                    0 non-null float64
# num_actv_rev_tl                   0 non-null float64
# num_bc_sats                       2008 non-null float64
# num_bc_tl                         0 non-null float64
# num_il_tl                         0 non-null float64
# num_op_rev_tl                     0 non-null float64
# num_rev_accts                     0 non-null float64
# num_rev_tl_bal_gt_0               0 non-null float64
# num_sats                          2008 non-null float64
# num_tl_120dpd_2m                  0 non-null float64
# num_tl_30dpd                      0 non-null float64
# num_tl_90g_dpd_24m                0 non-null float64
# num_tl_op_past_12m                0 non-null float64
# pct_tl_nvr_dlq                    0 non-null float64
# percent_bc_gt_75                  8827 non-null float64
# pub_rec_bankruptcies              14967 non-null int64
# tax_liens                         14967 non-null int64
# tot_hi_cred_lim                   0 non-null float64
# total_bal_ex_mort                 8942 non-null float64
# total_bc_limit                    8942 non-null float64
# total_il_high_credit_limit        0 non-null float64
# dtypes: category(9), datetime64[ns](5), float64(54), int64(16), object(9)
# memory usage: 9.8+ MB

# %% [markdown]
# # Check out summary stats on the numeric fields

# %%
past_loans.describe().transpose() #.to_string()
# Out:
#                                 count            mean           std  \
# member_id                       14967  1455102.984499  95085.641457
# loan_amnt                       14967    11601.224360   7188.093122
# funded_amnt                     14967    11601.224360   7188.093122
# funded_amnt_inv                 14967    11577.779687   7173.743526
# int_rate                        14967        0.118843      0.037323
# installment                     14967      387.315191    246.678443
# annual_inc                      14967    66678.824698  43712.992175
# dti                             14967       14.849731      6.776538
# delinq_2yrs                     14967        0.131422      0.505779
# inq_last_6mths                  14967        0.766553      0.983709
# mths_since_last_delinq           4777       38.594515     21.238001
# mths_since_last_record            434       93.322581     22.385497
# open_acc                        14967        9.908933      4.279092
# pub_rec                         14967        0.029665      0.174712
# revol_bal                       14967    13509.266854  12519.771355
# total_acc                       14967       21.852743     10.621712
# out_prncp                       14967        0.000000      0.000000
# out_prncp_inv                   14967        0.000000      0.000000
# total_pymnt                     14967    12629.793503   8628.024146
# total_pymnt_inv                 14967    12610.997262   8616.879588
# total_rec_prncp                 14967    10658.862063   7287.732960
# total_rec_int                   14967     1895.195312   1696.418596
# total_rec_late_fee              14967        0.792168      5.456035
# recoveries                      14967       74.943951    409.042144
# collection_recovery_fee         14967        4.721607     54.859303
# last_pymnt_amnt                 14967     2693.840138   4196.354440
# collections_12_mths_ex_med      14967        0.000000      0.000000
# mths_since_last_major_derog         0             NaN           NaN
# policy_code                     14967        1.000000      0.000000
# acc_now_delinq                  14967        0.000000      0.000000
# ...                               ...             ...           ...
# mo_sin_old_rev_tl_op                0             NaN           NaN
# mo_sin_rcnt_rev_tl_op               0             NaN           NaN
# mo_sin_rcnt_tl                      0             NaN           NaN
# mort_acc                         8942        1.304742      2.035491
# mths_since_recent_bc             8840       23.718100     27.306367
# mths_since_recent_bc_dlq            0             NaN           NaN
# mths_since_recent_inq            7580        7.079947      6.255791
# mths_since_recent_revol_delinq   2138       40.313377     20.749842
# num_accts_ever_120_pd               0             NaN           NaN
# num_actv_bc_tl                      0             NaN           NaN
# num_actv_rev_tl                     0             NaN           NaN
# num_bc_sats                      2008        4.646414      2.470650
# num_bc_tl                           0             NaN           NaN
# num_il_tl                           0             NaN           NaN
# num_op_rev_tl                       0             NaN           NaN
# num_rev_accts                       0             NaN           NaN
# num_rev_tl_bal_gt_0                 0             NaN           NaN
# num_sats                         2008       10.938745      4.703647
# num_tl_120dpd_2m                    0             NaN           NaN
# num_tl_30dpd                        0             NaN           NaN
# num_tl_90g_dpd_24m                  0             NaN           NaN
# num_tl_op_past_12m                  0             NaN           NaN
# pct_tl_nvr_dlq                      0             NaN           NaN
# percent_bc_gt_75                 8827       50.316382     35.458767
# pub_rec_bankruptcies            14967        0.023786      0.153260
# tax_liens                       14967        0.000000      0.000000
# tot_hi_cred_lim                     0             NaN           NaN
# total_bal_ex_mort                8942    34795.245023  33476.214916
# total_bc_limit                   8942    18805.242228  18696.834220
# total_il_high_credit_limit          0             NaN           NaN
#
#                                       min             25%           50%  \
# member_id                       382664.00  1383155.500000  1456996.0000
# loan_amnt                         1000.00     6325.000000    10000.0000
# funded_amnt                       1000.00     6325.000000    10000.0000
# funded_amnt_inv                    950.00     6300.000000    10000.0000
# int_rate                             0.06        0.089000        0.1212
# installment                         30.44      208.750000      337.3800
# annual_inc                        5000.00    40000.000000    57000.0000
# dti                                  0.00        9.750000       14.9000
# delinq_2yrs                          0.00        0.000000        0.0000
# inq_last_6mths                       0.00        0.000000        0.0000
# mths_since_last_delinq               1.00       21.000000       37.0000
# mths_since_last_record               1.00       89.000000       99.0000
# open_acc                             2.00        7.000000        9.0000
# pub_rec                              0.00        0.000000        0.0000
# revol_bal                            0.00     5949.500000    10687.0000
# total_acc                            3.00       14.000000       20.0000
# out_prncp                            0.00        0.000000        0.0000
# out_prncp_inv                        0.00        0.000000        0.0000
# total_pymnt                          0.00     6524.541549    11029.1800
# total_pymnt_inv                      0.00     6509.480000    11006.6800
# total_rec_prncp                      0.00     5400.000000     9600.0000
# total_rec_int                        0.00      770.820000     1428.5000
# total_rec_late_fee                   0.00        0.000000        0.0000
# recoveries                           0.00        0.000000        0.0000
# collection_recovery_fee              0.00        0.000000        0.0000
# last_pymnt_amnt                      0.00      304.865000      663.8600
# collections_12_mths_ex_med           0.00        0.000000        0.0000
# mths_since_last_major_derog           NaN             NaN           NaN
# policy_code                          1.00        1.000000        1.0000
# acc_now_delinq                       0.00        0.000000        0.0000
# ...                                   ...             ...           ...
# mo_sin_old_rev_tl_op                  NaN             NaN           NaN
# mo_sin_rcnt_rev_tl_op                 NaN             NaN           NaN
# mo_sin_rcnt_tl                        NaN             NaN           NaN
# mort_acc                             0.00        0.000000        0.0000
# mths_since_recent_bc                 0.00        6.000000       13.0000
# mths_since_recent_bc_dlq              NaN             NaN           NaN
# mths_since_recent_inq                0.00        2.000000        5.0000
# mths_since_recent_revol_delinq       1.00       24.000000       40.0000
# num_accts_ever_120_pd                 NaN             NaN           NaN
# num_actv_bc_tl                        NaN             NaN           NaN
# num_actv_rev_tl                       NaN             NaN           NaN
# num_bc_sats                          0.00        3.000000        4.0000
# num_bc_tl                             NaN             NaN           NaN
# num_il_tl                             NaN             NaN           NaN
# num_op_rev_tl                         NaN             NaN           NaN
# num_rev_accts                         NaN             NaN           NaN
# num_rev_tl_bal_gt_0                   NaN             NaN           NaN
# num_sats                             2.00        8.000000       10.0000
# num_tl_120dpd_2m                      NaN             NaN           NaN
# num_tl_30dpd                          NaN             NaN           NaN
# num_tl_90g_dpd_24m                    NaN             NaN           NaN
# num_tl_op_past_12m                    NaN             NaN           NaN
# pct_tl_nvr_dlq                        NaN             NaN           NaN
# percent_bc_gt_75                     0.00       20.000000       50.0000
# pub_rec_bankruptcies                 0.00        0.000000        0.0000
# tax_liens                            0.00        0.000000        0.0000
# tot_hi_cred_lim                       NaN             NaN           NaN
# total_bal_ex_mort                    0.00    14388.500000    26173.5000
# total_bc_limit                       0.00     7200.000000    13400.0000
# total_il_high_credit_limit            NaN             NaN           NaN
#
#                                            75%             max
# member_id                       1531193.000000  1622372.000000
# loan_amnt                         15000.000000    35000.000000
# funded_amnt                       15000.000000    35000.000000
# funded_amnt_inv                   15000.000000    35000.000000
# int_rate                              0.142700        0.248900
# installment                         496.800000     1379.230000
# annual_inc                        80000.000000  1233000.000000
# dti                                  20.020000       34.920000
# delinq_2yrs                           0.000000       10.000000
# inq_last_6mths                        1.000000        8.000000
# mths_since_last_delinq               54.000000      108.000000
# mths_since_last_record              108.000000      119.000000
# open_acc                             12.000000       49.000000
# pub_rec                               0.000000        4.000000
# revol_bal                         17484.000000   149509.000000
# total_acc                            28.000000       68.000000
# out_prncp                             0.000000        0.000000
# out_prncp_inv                         0.000000        0.000000
# total_pymnt                       16435.163946    49567.279975
# total_pymnt_inv                   16422.540000    49567.280000
# total_rec_prncp                   14000.000000    35000.000000
# total_rec_int                      2440.980000    14552.280000
# total_rec_late_fee                    0.000000      134.010000
# recoveries                            0.000000    15581.060000
# collection_recovery_fee               0.000000     3703.430000
# last_pymnt_amnt                    3516.195000    35285.310000
# collections_12_mths_ex_med            0.000000        0.000000
# mths_since_last_major_derog                NaN             NaN
# policy_code                           1.000000        1.000000
# acc_now_delinq                        0.000000        0.000000
# ...                                        ...             ...
# mo_sin_old_rev_tl_op                       NaN             NaN
# mo_sin_rcnt_rev_tl_op                      NaN             NaN
# mo_sin_rcnt_tl                             NaN             NaN
# mort_acc                              2.000000       22.000000
# mths_since_recent_bc                 34.000000      413.000000
# mths_since_recent_bc_dlq                   NaN             NaN
# mths_since_recent_inq                11.000000       24.000000
# mths_since_recent_revol_delinq       56.000000       98.000000
# num_accts_ever_120_pd                      NaN             NaN
# num_actv_bc_tl                             NaN             NaN
# num_actv_rev_tl                            NaN             NaN
# num_bc_sats                           6.000000       20.000000
# num_bc_tl                                  NaN             NaN
# num_il_tl                                  NaN             NaN
# num_op_rev_tl                              NaN             NaN
# num_rev_accts                              NaN             NaN
# num_rev_tl_bal_gt_0                        NaN             NaN
# num_sats                             14.000000       37.000000
# num_tl_120dpd_2m                           NaN             NaN
# num_tl_30dpd                               NaN             NaN
# num_tl_90g_dpd_24m                         NaN             NaN
# num_tl_op_past_12m                         NaN             NaN
# pct_tl_nvr_dlq                             NaN             NaN
# percent_bc_gt_75                     80.000000      100.000000
# pub_rec_bankruptcies                  0.000000        2.000000
# tax_liens                             0.000000        0.000000
# tot_hi_cred_lim                            NaN             NaN
# total_bal_ex_mort                 43766.500000   819312.000000
# total_bc_limit                    24100.000000   301720.000000
# total_il_high_credit_limit                 NaN             NaN
#
# [70 rows x 8 columns]

# %% [markdown]
# ## Explore date fields

# %%
past_loans.groupby(past_loans['last_pymnt_d'].map(lambda x: x.year))

# %%
pd.unique(past_loans.sort_values('last_pymnt_d')['last_pymnt_d'])
# Out:
# array(['2012-01-31T19:00:00.000000000-0500',
#        '2012-02-29T19:00:00.000000000-0500',
#        '2012-03-31T20:00:00.000000000-0400',
#        '2012-04-30T20:00:00.000000000-0400',
#        '2012-05-31T20:00:00.000000000-0400',
#        '2012-06-30T20:00:00.000000000-0400',
#        '2012-07-31T20:00:00.000000000-0400',
#        '2012-08-31T20:00:00.000000000-0400',
#        '2012-09-30T20:00:00.000000000-0400',
#        '2012-10-31T20:00:00.000000000-0400',
#        '2012-11-30T19:00:00.000000000-0500',
#        '2012-12-31T19:00:00.000000000-0500',
#        '2013-01-31T19:00:00.000000000-0500',
#        '2013-02-28T19:00:00.000000000-0500',
#        '2013-03-31T20:00:00.000000000-0400',
#        '2013-04-30T20:00:00.000000000-0400',
#        '2013-05-31T20:00:00.000000000-0400',
#        '2013-06-30T20:00:00.000000000-0400',
#        '2013-07-31T20:00:00.000000000-0400',
#        '2013-08-31T20:00:00.000000000-0400',
#        '2013-09-30T20:00:00.000000000-0400',
#        '2013-10-31T20:00:00.000000000-0400',
#        '2013-11-30T19:00:00.000000000-0500',
#        '2013-12-31T19:00:00.000000000-0500',
#        '2014-01-31T19:00:00.000000000-0500',
#        '2014-02-28T19:00:00.000000000-0500',
#        '2014-03-31T20:00:00.000000000-0400',
#        '2014-04-30T20:00:00.000000000-0400',
#        '2014-05-31T20:00:00.000000000-0400',
#        '2014-06-30T20:00:00.000000000-0400',
#        '2014-07-31T20:00:00.000000000-0400',
#        '2014-08-31T20:00:00.000000000-0400',
#        '2014-09-30T20:00:00.000000000-0400',
#        '2014-10-31T20:00:00.000000000-0400',
#        '2014-11-30T19:00:00.000000000-0500',
#        '2014-12-31T19:00:00.000000000-0500',
#        '2015-01-31T19:00:00.000000000-0500',
#        '2015-02-28T19:00:00.000000000-0500',
#        '2015-03-31T20:00:00.000000000-0400',
#        '2015-04-30T20:00:00.000000000-0400',
#        '2015-05-31T20:00:00.000000000-0400',
#        '2015-06-30T20:00:00.000000000-0400',
#        '2015-07-31T20:00:00.000000000-0400',
#        '2015-08-31T20:00:00.000000000-0400',
#        '2015-09-30T20:00:00.000000000-0400',
#        '2015-10-31T20:00:00.000000000-0400', 'NaT'], dtype='datetime64[ns]')

# %%
pd.unique(past_loans['issue_d'])
# Out:
# array(['2012-05-31T20:00:00.000000000-0400',
#        '2012-04-30T20:00:00.000000000-0400',
#        '2012-03-31T20:00:00.000000000-0400',
#        '2012-02-29T19:00:00.000000000-0500',
#        '2012-01-31T19:00:00.000000000-0500',
#        '2011-12-31T19:00:00.000000000-0500'], dtype='datetime64[ns]')

# %% [raw]
# Scatter plot of default frequency vs (last payment - issue date), maybe group by

# %% [markdown]
# # Fill in rows for each date to last payment
# A simple look at the data will be skewed because active loans may still default in the future. Only using 2012 36 month loans.
#
# The data is supplied with status for each loan. Best to fill data with records for each month from loan start (and status = current) until today or last payment). This will allow me to determine the shape of the conditional default curve (what percentage of current loans default vs age?) and then use the current data set. I will also gain a better understanding of Loss Given Default for this data set.
#
# Not sure if I have time to make this happen. When I do, I will go back and import data from 2013+.

# %% [markdown]
# ## Create list of possible dates to match with

# %%
# What are all the dates in the table?
# for each date, what are the earlier dates
# create new table with "current" until paid or written off
# table should stop before defaults and late payments start registering

# %%
all_dates = pd.DataFrame(index=pd.unique(past_loans.sort_values('last_pymnt_d')['last_pymnt_d']))#, columns='date_d')
all_dates['report_d'] = pd.unique(past_loans.sort_values('last_pymnt_d')['last_pymnt_d'])
all_dates['common'] = 1
all_dates.dropna(how = 'any')
all_dates[(pd.notnull(all_dates['report_d']))]
# Out:
#              report_d  common
# 2014-02-01 2014-02-01       1
# 2014-03-01 2014-03-01       1
# 2014-04-01 2014-04-01       1
# 2014-05-01 2014-05-01       1
# 2014-06-01 2014-06-01       1
# 2014-07-01 2014-07-01       1
# 2014-08-01 2014-08-01       1
# 2014-09-01 2014-09-01       1
# 2014-10-01 2014-10-01       1
# 2014-11-01 2014-11-01       1
# 2014-12-01 2014-12-01       1
# 2015-01-01 2015-01-01       1
# 2015-02-01 2015-02-01       1
# 2015-03-01 2015-03-01       1
# 2015-04-01 2015-04-01       1
# 2015-05-01 2015-05-01       1
# 2015-06-01 2015-06-01       1
# 2015-07-01 2015-07-01       1
# 2015-08-01 2015-08-01       1
# 2015-09-01 2015-09-01       1
# 2015-10-01 2015-10-01       1
# 2015-11-01 2015-11-01       1
# 2015-12-01 2015-12-01       1

# %%
# ro's idea - just loop through the data to create the data

# past_loans['common'] = 1
# partly_merged = pd.merge(past_loans, all_dates, on = 'common')
# full_past_loans = partly_merged[(partly_merged['last_pymnt_d'] >= partly_merged['report_d'] & 
#                                 pd.notnull(partly_merged['report_d']))]
# full_past_loans.head(100)

# %% [markdown]
# # Create dependent and independent data

# %%
X = past_loans.drop('loan_status', axis = 1)
y = past_loans['loan_status']

# %% [markdown]
# # Split into training and test data

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
# 10 cross validation iterations with 20% test / 80% train
from sklearn.cross_validation import ShuffleSplit
cv = ShuffleSplit(X_train.shape[0], n_iter=10, test_size=0.2, random_state=0)

# %% [markdown]
# # Standardize the data

# %%
from sklearn.preprocessing import StandardScaler
stdsc = StandardScaler()
# transform our training features
X_train_std = stdsc.fit_transform(X_train)
# transform the testing features in the same way
X_test_std = stdsc.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-bb51522ae088> in <module>()
#       2 stdsc = StandardScaler()
#       3 # transform our training features
# ----> 4 X_train_std = stdsc.fit_transform(X_train)
#       5 # transform the testing features in the same way
#       6 X_test_std = stdsc.transform(X_test)
#
# //anaconda/lib/python2.7/site-packages/sklearn/base.pyc in fit_transform(self, X, y, **fit_params)
#     431         if y is None:
#     432             # fit method of arity 1 (unsupervised transformation)
# --> 433             return self.fit(X, **fit_params).transform(X)
#     434         else:
#     435             # fit method of arity 2 (supervised transformation)
#
# //anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in fit(self, X, y)
#     346         """
#     347         X = check_array(X, accept_sparse='csr', copy=self.copy,
# --> 348                         ensure_2d=False)
#     349         if warn_if_not_float(X, estimator=self):
#     350             X = X.astype(np.float)
#
# //anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features)
#     345         # make sure we actually converted to numeric:
#     346         if dtype_numeric and array.dtype.kind == "O":
# --> 347             array = array.astype(np.float64)
#     348         if not allow_nd and array.ndim >= 3:
#     349             raise ValueError("Found array with dim %d. Expected <= 2" %
#
# ValueError: could not convert string to float: INDIVIDUAL
