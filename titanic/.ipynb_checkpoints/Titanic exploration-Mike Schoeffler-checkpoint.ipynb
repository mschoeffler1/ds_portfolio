# %% [markdown]
# # *Titanic exploration*
#
# Problem based on: https://www.kaggle.com/c/titanic
#
# 1. **Read in data** - class supplied a csv file
# 1. **Explore data**
#
#
# - Needs visuals and text to answer every question
# - Expects 3-5 hours (really good at it will take an hour)
#
# ## **Homework questions**
#
# 1. **What do you notice about the data? Any issues?**
#   - The "Name" field is unstructured, with nicknames, maiden and married names, etc.
#   - Unknown cabins show as NaN
#   - Some field headings are not easily interpreted (SibSp, Parch)
#   - Meanings for data in some fields is not obvious (Ticket code, Embarcation code)
# 1. **What role does gender play in surviving?**
# 1. **What role does class play in surviving?**
# 1. **What role does age play in surviving?**
# 1. **Do you have any ideas for new features?**
#   - Cabin in initial damage zone - maybe some of the third class passengers died for reasons other than class
#   - Ethnicity (by last name) - maybe some ethnicities were favored beyond ticket class
#   - Marital status - derived from name field
#   - Travelling with family - derived from other passengers

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# use ggplot style for all graphics
plt.style.use('ggplot');
# use this for interactive mode, but may reduce performance/battery life
#%matplotlib nbagg

# %%
# create dataframe to hold titanic data
df = pd.read_csv("/Users/michaelschoeffler/Documents/ds_portfolio/titanic/titanic_dropna.csv")
# modify dataframe to sort by last name - will help look for anomalies
# df = df.sort_values(by="Name")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              7         0       1
# 6              8         0       3
# 7              9         1       3
# 8             10         1       2
# 9             11         1       3
# 10            12         1       1
# 11            13         0       3
# 12            14         0       3
# 13            15         0       3
# 14            16         1       2
# 15            17         0       3
# 16            19         0       3
# 17            21         0       2
# 18            22         1       2
# 19            23         1       3
# 20            24         1       1
# 21            25         0       3
# 22            26         1       3
# 23            28         0       1
# 24            31         0       1
# ...

# %% [markdown]
# **How did class affect survival?**
#
# The survival rate was better in first class (65%) than in second class (48%) than in third class (24%).

# %%
df.groupby(['Pclass']).mean()
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        464.157609  0.652174  38.105543  0.456522  0.413043  88.048121
# 2        447.156069  0.479769  29.877630  0.427746  0.404624  21.471556
# 3        441.219718  0.239437  25.140620  0.585915  0.456338  13.229435

# %%
# df['Survived'].plot();
df['Age'].plot(kind='hist');
# df['Survived'].hist(by=np.random.randint(0, 4, 1000))

# %%
df.plot(kind='scatter', x='Age', y = 'Survived', alpha = 0.1);
# df.plot(kind='scatter', x='Sex', y = 'Survived');

# %%
# modify dataframe to show title, maiden name
# df['Name'].str.split(',',expand=True, n=1)
# df.insert(4, 'last_name', df['Name'].str.split(',',expand=True, n=1)[0])
df.insert(4, 'last_name', 'title', df['Name'].str.split(',',expand=True, n=2)[0])
# df['last_name'] = df['Name'].str.split(',',expand=True, n=1)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-49ac7a97b4f9> in <module>()
#       2 # df['Name'].str.split(',',expand=True, n=1)
#       3 # df.insert(4, 'last_name', df['Name'].str.split(',',expand=True, n=1)[0])
# ----> 4 df.insert(4, 'last_name', 'title', df['Name'].str.split(',',expand=True, n=2)[0])
#       5 # df['last_name'] = df['Name'].str.split(',',expand=True, n=1)
#       6 df
#
# //anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in insert(self, loc, column, value, allow_duplicates)
#    2335         value = self._sanitize_column(column, value)
#    2336         self._data.insert(
# -> 2337             loc, column, value, allow_duplicates=allow_duplicates)
#    2338
#    2339     def assign(self, **kwargs):
#
# //anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in insert(self, loc, item, value, allow_duplicates)
#    3313
# ...

# %%
# create plots to show effect of fields on survivorship
df['Survived'].interpolate.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c99197b8e411> in <module>()
#       1 # create plots to show effect of fields on survivorship
# ----> 2 df['Survived'].interpolate.plot()
#
# NameError: name 'df' is not defined

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=['A', 'B', 'C', 'D'])

df = df.cumsum()

plt.figure(); df.plot(); plt.legend(loc='best')

# %%
df.plot?
